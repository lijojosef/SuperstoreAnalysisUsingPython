# %%
import pandas as pd

orderWeek = pd.read_excel('OrderWeek.xlsx')

print(orderWeek)
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     23429       Critical      0.10        4.13           0.50         3367
# 1     26104         Medium      0.06        7.10           6.05         3369
# 2     18311         Medium      0.01      179.29          29.21         3374
# 3     18320           High      0.05       73.98          12.14         3374
# 4     18321           High      0.00        5.98           7.15         3374
# ..      ...            ...       ...         ...            ...          ...
# 103   24802         Medium      0.04        7.96           4.95         3361
# 104   23887         Medium      0.03        4.98           4.95         3361
# 105   19749            Low      0.10       80.97          33.60         3366
# 106   19750            Low      0.02        6.48           5.11         3366
# 107   23428       Critical      0.08       30.97           4.00         3367
#
# ...

# %%
orderWeek.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   23429       Critical      0.10        4.13           0.50         3367
# 1   26104         Medium      0.06        7.10           6.05         3369
# 2   18311         Medium      0.01      179.29          29.21         3374
# 3   18320           High      0.05       73.98          12.14         3374
# 4   18321           High      0.00        5.98           7.15         3374
#
#     Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0  Renee McKenzie     Express Air      Home Office  Office Supplies  ...
# 1     Stacy Byrne     Regular Air      Home Office  Office Supplies  ...
# 2      Jamie Ward  Delivery Truck        Corporate        Furniture  ...
# 3      Jamie Ward     Regular Air      Home Office       Technology  ...
# 4      Jamie Ward     Regular Air      Home Office  Office Supplies  ...
#
#   Region State or Province             City  Postal Code Order Date  \
# ...

# %%
orderWeek.tail()
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 103   24802         Medium      0.04        7.96           4.95         3361
# 104   23887         Medium      0.03        4.98           4.95         3361
# 105   19749            Low      0.10       80.97          33.60         3366
# 106   19750            Low      0.02        6.48           5.11         3366
# 107   23428       Critical      0.08       30.97           4.00         3367
#
#       Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 103    Oscar Kenney     Regular Air      Home Office        Furniture  ...
# 104    Oscar Kenney     Regular Air      Home Office  Office Supplies  ...
# 105      Dana Boyle  Delivery Truck      Home Office       Technology  ...
# 106      Dana Boyle     Regular Air      Home Office  Office Supplies  ...
# 107  Renee McKenzie     Regular Air      Home Office       Technology  ...
#
# ...

# %%
orderWeek.describe()
# Out:
#              Row ID    Discount   Unit Price  Shipping Cost  Customer ID  \
# count    108.000000  108.000000   108.000000     108.000000   108.000000
# mean   21329.444444    0.046574    65.477500       9.988426  3323.629630
# std     3269.259236    0.031151   142.950605      13.237251    52.447676
# min     2986.000000    0.000000     1.700000       0.500000  3226.000000
# 25%    19463.250000    0.020000     6.480000       2.990000  3279.000000
# 50%    21577.500000    0.050000    16.360000       5.745000  3338.500000
# 75%    23301.500000    0.070000    75.727500       8.990000  3366.250000
# max    26208.000000    0.100000  1270.990000      70.200000  3403.000000
#
#        Product Base Margin   Postal Code       Profit  Quantity ordered new  \
# count           105.000000    108.000000   108.000000            108.000000
# mean              0.504190  49770.583333   261.234191             11.490741
# std               0.132917  30735.537109   970.665502              9.714134
# ...

# %%
orderWeek.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                108 non-null    int64
#  1   Order Priority        108 non-null    object
#  2   Discount              108 non-null    float64
#  3   Unit Price            108 non-null    float64
#  4   Shipping Cost         108 non-null    float64
#  5   Customer ID           108 non-null    int64
#  6   Customer Name         108 non-null    object
#  7   Ship Mode             108 non-null    object
#  8   Customer Segment      108 non-null    object
#  9   Product Category      108 non-null    object
#  10  Product Sub-Category  108 non-null    object
#  11  Product Container     108 non-null    object
#  12  Product Name          108 non-null    object
#  13  Product Base Margin   105 non-null    float64
#  14  Country               108 non-null    object
# ...

# %%
orderHistorical = pd.read_excel('OrderHistoricalData.xlsx')

print(orderHistorical)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1839   25605           High      0.04       39.48           1.99         3222
# 1840   25606           High      0.00        8.12           2.83         3222
# 1841   19517       Critical      0.06       60.98          30.00         3224
# 1842   22291  Not Specified      0.10      208.16          68.02         3225
# 1843   22292  Not Specified      0.07       90.48          19.99         3226
#
# ...

# %%
orderHistorical.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
orderHistorical.tail()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1839   25605           High      0.04       39.48           1.99         3222
# 1840   25606           High      0.00        8.12           2.83         3222
# 1841   19517       Critical      0.06       60.98          30.00         3224
# 1842   22291  Not Specified      0.10      208.16          68.02         3225
# 1843   22292  Not Specified      0.07       90.48          19.99         3226
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 1839        Diane Lu     Express Air        Corporate       Technology  ...
# 1840        Diane Lu     Regular Air        Corporate       Technology  ...
# 1841   Claudia White  Delivery Truck   Small Business        Furniture  ...
# 1842  Robyn Crawford  Delivery Truck   Small Business  Office Supplies  ...
# 1843     Arthur Gold     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
orderHistorical.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   1844.000000  1844.000000  1844.000000    1844.000000  1844.000000
# mean   19833.724512     0.049116   111.632901      13.142668  1642.355206
# std     6068.646364     0.031394   403.232088      17.615820   939.763685
# min       64.000000     0.000000     1.140000       0.490000     3.000000
# 25%    19107.750000     0.020000     6.480000       3.290000   816.500000
# 50%    21133.500000     0.050000    20.990000       6.190000  1659.000000
# 75%    23513.250000     0.080000   100.980000      14.490000  2468.000000
# max    26389.000000     0.210000  6783.020000     164.730000  3226.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          1831.000000   1844.000000   1844.000000           1844.000000
# mean              0.515816  51638.094902    106.217093             13.029826
# ...

# %%
orderHistorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1844 non-null   int64
#  1   Order Priority        1844 non-null   object
#  2   Discount              1844 non-null   float64
#  3   Unit Price            1844 non-null   float64
#  4   Shipping Cost         1844 non-null   float64
#  5   Customer ID           1844 non-null   int64
#  6   Customer Name         1844 non-null   object
#  7   Ship Mode             1844 non-null   object
#  8   Customer Segment      1844 non-null   object
#  9   Product Category      1844 non-null   object
#  10  Product Sub-Category  1844 non-null   object
#  11  Product Container     1844 non-null   object
#  12  Product Name          1844 non-null   object
#  13  Product Base Margin   1831 non-null   float64
#  14  Country               1844 non-null   object
# ...

# %%
user = pd.read_csv("user.csv")
print(user)
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
temp = pd.concat([orderHistorical, orderWeek])
print(temp)
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     20847           High      0.01        2.84           0.93            3
# 1     20228  Not Specified      0.02      500.98          26.00            5
# 2     21776       Critical      0.06        9.48           7.29           11
# 3     24844         Medium      0.09       78.69          19.99           14
# 4     24846         Medium      0.08        3.28           2.31           14
# ..      ...            ...       ...         ...            ...          ...
# 103   24802         Medium      0.04        7.96           4.95         3361
# 104   23887         Medium      0.03        4.98           4.95         3361
# 105   19749            Low      0.10       80.97          33.60         3366
# 106   19750            Low      0.02        6.48           5.11         3366
# 107   23428       Critical      0.08       30.97           4.00         3367
#
# ...

# %%
result = pd.merge(temp, user, on = "Region")
print(result)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      23890           High      0.05       26.48           6.93           18
# 3      24063  Not Specified      0.07       12.99           9.44           19
# 4      20631           High      0.06       55.48          14.30           24
# ...      ...            ...       ...         ...            ...          ...
# 1947   25613           High      0.03        2.61           0.50         3339
# 1948   25614           High      0.01       11.66           7.95         3339
# 1949   18947         Medium      0.07        7.68           6.16         3347
# 1950   18948         Medium      0.05        6.64           4.95         3347
# 1951   19461         Medium      0.02      110.99           2.50         3347
#
# ...

# %%
result.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   23890           High      0.05       26.48           6.93           18
# 3   24063  Not Specified      0.07       12.99           9.44           19
# 4   20631           High      0.06       55.48          14.30           24
#
#     Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0   Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1  Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2    Laurie Hanna     Regular Air   Small Business        Furniture  ...
# 3     Jim Rodgers     Regular Air   Small Business       Technology  ...
# 4     Edna Thomas     Regular Air        Corporate  Office Supplies  ...
#
#   State or Province           City Postal Code  Order Date  Ship Date  \
# ...

# %%
result.to_excel("output/result.xlsx",sheet_name='resultConnect',index= True)
